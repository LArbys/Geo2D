# %%
# %matplotlib inline
#%pylab
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mpc
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.patches as patches
import scipy
from scipy import interpolate
import pandas as pd
import itertools
from root_numpy import root2array, root2rec, tree2rec, array2root
import ROOT
from ROOT import geo2d
geo2d.load_pyutil
from ROOT.cv import Point_ as Vector2D
DTYPE='float'
pdraw = geo2d.PyDraw()

# %%
# Define range
xmin,xmax = (-4,8)
ymin,ymax = (-4,8)

# Define circle
c=geo2d.Circle(DTYPE)()
c.center.x, c.center.y = (1., 1.)
c.radius = 2.

# Define line
l=geo2d.Line(DTYPE)(1,1,45)
line_pt_x=[xmin, xmax]
line_pt_y=[l.y(xmin), l.y(xmax)]

# Calculate intersections
xs_pts = geo2d.Intersection(c,l)
print xs_pts.size(),'crossing points'

# Plot
fig,ax = plt.subplots(figsize=(4,4))
cplt = plt.Circle((c.center.x,c.center.y),c.radius,color='b')
ax.add_artist(cplt)
plt.plot(line_pt_x, line_pt_y, marker='',linestyle='-',color='r')
for i in xrange(xs_pts.size()):
    pt = xs_pts[i]
    plt.plot([pt.x],[pt.y],marker='o',color='r')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.show()

# %%
# Define range
xmin,xmax = (-4,8)
ymin,ymax = (-4,8)

# Prepare canvas
fig,ax = plt.subplots(figsize=(4,4))

# Define circle
c=geo2d.Circle(DTYPE)()
c.center.x, c.center.y = (1., 1.)
c.radius = 2.
cplt = plt.Circle((c.center.x,c.center.y),c.radius,color='b')
ax.add_artist(cplt)

# Define many lines
for xpos in np.arange(xmin,xmax,(xmax-xmin)/20.):
    l=geo2d.Line(DTYPE)(xpos,ymin,90)
    line_pt_x=[xpos, xpos]
    line_pt_y=[ymin, ymax]

    # Calculate intersections
    xs_pts = geo2d.Intersection(c,l)
    #print 'x=',xpos,'has',xs_pts.size(),'crossing points'

    # Plot
    plt.plot(line_pt_x, line_pt_y, marker='',linestyle='-',color='r')
    for i in xrange(xs_pts.size()):
        pt = xs_pts[i]
        plt.plot([pt.x],[pt.y],marker='o',color='r')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.show()

# %%
# Define range
xmin,xmax = (-4,8)
ymin,ymax = (-4,8)

# Prepare canvas
fig,ax = plt.subplots(figsize=(4,4))

# Define circle
c=geo2d.Circle(DTYPE)()
c.center.x, c.center.y = (1., 1.)
c.radius = 2.
cplt = plt.Circle((c.center.x,c.center.y),c.radius,color='b')
ax.add_artist(cplt)

# Define many lines
for angle in np.arange(0,90,5):
    l=geo2d.Line(DTYPE)(xmin,ymin,angle)
    line_pt_x=[xmin, xmax]
    line_pt_y=[l.y(xmin), l.y(xmax)]

    # Calculate intersections
    xs_pts = geo2d.Intersection(c,l)
    #print 'angle',angle,'has',xs_pts.size(),'crossing points'

    # Plot
    plt.plot(line_pt_x, line_pt_y, marker='',linestyle='-',color='r')
    for i in xrange(xs_pts.size()):
        pt = xs_pts[i]
        plt.plot([pt.x],[pt.y],marker='o',color='r')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.show()

# %%
# Define range
xmin,xmax = (-4,8)
ymin,ymax = (-4,8)

# Prepare canvas
fig,ax = plt.subplots(figsize=(4,4))

# Define circle
c=geo2d.Circle(DTYPE)()
c.center.x, c.center.y = (1., 1.)
c.radius = 2.
cplt = plt.Circle((c.center.x,c.center.y),c.radius,color='b')
ax.add_artist(cplt)

# Define many lines
for angle in np.arange(0,90,5):
    l=geo2d.Line(DTYPE)(1,1,angle)
    line_pt_x=[xmin, xmax]
    line_pt_y=[l.y(xmin), l.y(xmax)]

    # Calculate intersections
    xs_pts = geo2d.Intersection(c,l)
    #print 'angle',angle,'has',xs_pts.size(),'crossing points'

    # Plot
    plt.plot(line_pt_x, line_pt_y, marker='',linestyle='-',color='r')
    for i in xrange(xs_pts.size()):
        pt = xs_pts[i]
        plt.plot([pt.x],[pt.y],marker='o',color='r')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.show()

# %%
# Define range
xmin,xmax = (-4,8)
ymin,ymax = (-4,8)

# Prepare canvas
fig,ax = plt.subplots(figsize=(4,4))

# Define circle
c=geo2d.Circle(DTYPE)()
c.center.x, c.center.y = (1., 1.)
c.radius = 2.
cplt = plt.Circle((c.center.x,c.center.y),c.radius,color='b')
ax.add_artist(cplt)

# Define many lines
for angle in np.arange(0,90,5):
    l=geo2d.HalfLine(DTYPE)(1,1,angle)
    line_pt_x=[1, xmax]
    line_pt_y=[l.y(1), l.y(xmax)]

    # Calculate intersections
    xs_pts = geo2d.Intersection(c,l)
    #print 'angle',angle,'has',xs_pts.size(),'crossing points'

    # Plot
    plt.plot(line_pt_x, line_pt_y, marker='',linestyle='-',color='r')
    for i in xrange(xs_pts.size()):
        pt = xs_pts[i]
        plt.plot([pt.x],[pt.y],marker='o',color='r')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.show()

# %%
# Define range
xmin,xmax = (-4,8)
ymin,ymax = (-4,8)

# Prepare canvas
fig,ax = plt.subplots(figsize=(4,4))

# Define circle
c=geo2d.Circle(DTYPE)()
c.center.x, c.center.y = (1., 1.)
c.radius = 3.
cplt = plt.Circle((c.center.x,c.center.y),c.radius,color='b')
ax.add_artist(cplt)

# Define many lines
for angle in np.arange(0,90,5):
    d = geo2d.dir('float')(angle)
    pt1 = c.center + d * 1.0
    pt2 = c.center + d * 4.0
    l=geo2d.LineSegment(DTYPE)(pt1,pt2)
    line_pt_x=[pt1.x, pt2.x]
    line_pt_y=[pt1.y, pt2.y]

    # Calculate intersections
    xs_pts = geo2d.Intersection(c,l)
    #print 'angle',angle,'has',xs_pts.size(),'crossing points'

    # Plot
    plt.plot(line_pt_x, line_pt_y, marker='',linestyle='-',color='r')
    for i in xrange(xs_pts.size()):
        pt = xs_pts[i]
        plt.plot([pt.x],[pt.y],marker='o',color='r')
# Define many lines
for angle in np.arange(-180,-90,5):
    d = geo2d.dir('float')(angle)
    pt1 = c.center + d * 1.0
    pt2 = c.center + d * 4.0
    l=geo2d.LineSegment(DTYPE)(pt1,pt2)
    line_pt_x=[pt1.x, pt2.x]
    line_pt_y=[pt1.y, pt2.y]

    # Calculate intersections
    xs_pts = geo2d.Intersection(c,l)
    #print 'angle',angle,'has',xs_pts.size(),'crossing points'

    # Plot
    plt.plot(line_pt_x, line_pt_y, marker='',linestyle='-',color='r')
    for i in xrange(xs_pts.size()):
        pt = xs_pts[i]
        plt.plot([pt.x],[pt.y],marker='o',color='r')
plt.xlim(xmin,xmax)
plt.ylim(ymin,ymax)
plt.show()
